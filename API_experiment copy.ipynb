# %%
import requests

# URL endpoint API
url = "https://webapps.bps.go.id/nqaf/qgate/api/Notifications/fetchByUsername"                                      

# Payload yang akan dikirim (dengan format application/x-www-form-urlencoded)
payload = "year=2025"

# Header yang diperlukan
headers = {
    "Content-Type": "application/x-www-form-urlencoded; charset=UTF-8",
    "X-Requested-With": "XMLHttpRequest"
}

# Cookies yang diperlukan (diambil dari data request sebelumnya)
cookies = {
    "BIGipServeriapps_whfe01_443.app~iapps_whfe01_443_pool": "3710124042.20480.0000",
    "ci_session": "46cdef706524eadcf2bca262536279626087a2a1",
    "twk_idm_key": "ao_hIEnT1FL-QmUj1ksOA",
    "TawkConnectionTime": "0",
    "TS017b14ed": "0167a1c861baa5a79164c8d6b6ba8cf0ac6af0b0c05c77c5efbe86bcf48713ba10b575ee0e67280a11954e0d92d12dd24284b1b654",
    "TS0151fc2b": "0167a1c861aa1a52e39409f77273952748b2465b12f4b47701af17e1459fa8e8b33f1bee606fbd50dffd86294a9df5e6d5810657e2",
    "TS01038878": "0167a1c861ed411479f7a5e95d6eb582ad2615d0c13ae9f18ae4861bdacc9d15d3dad2cf5c1f429ebb5091adcbb2a2e7a7c2cac248",
    "TS014fcb37": "0167a1c861f035acb54671fe042ba31e61133220e9a8accd2a2c445e33e56a0abd409055991473cb30a1e88e25a26ca62081593d72",
    "TS01514aca": "0167a1c861e5ae77ed399ec0672c41cffc3f7ba06796bedb251f8dc9ff804c0dbb3227749f953bffb19f6e07b7fad51eab0368f1d47f387fe3daa900b2801b3dad123bdec925fc1232f133a9ba8305fa1b775ef86730b53bd2f47caf4532c2e125e6dd838e27c3943dcb26d833242b919a95f71b37"
}

try:
    # Mengirim request POST dengan payload, header, dan cookies
    response = requests.post(url, data=payload, headers=headers, cookies=cookies)
    response.raise_for_status()  # Akan menghasilkan exception jika status code bukan 200

    # Mencoba mengonversi response ke JSON
    try:
        data = response.json()
    except ValueError:
        data = response.text

    print("Data yang diterima:")
    print(data)

except requests.exceptions.RequestException as e:
    print("Terjadi error saat mengakses API:", e)
# Out:
# Data yang diterima:
# ...

# %%
import requests

# URL endpoint API Projects
url = "https://webapps.bps.go.id/nqaf/qgate/api/Projects/fetchAll"

# Payload dikirim sebagai data form (application/x-www-form-urlencoded)
payload = "year=2025"

# Header yang diperlukan
headers = {
    "Content-Type": "application/x-www-form-urlencoded; charset=UTF-8",
    "X-Requested-With": "XMLHttpRequest"
}

# Cookies yang digunakan, disesuaikan dengan data request
cookies = {
}

try:
    # Mengirim request POST ke endpoint dengan payload, header, dan cookies
    response = requests.post(url, data=payload, headers=headers, cookies=cookies)
    response.raise_for_status()  # Menimbulkan exception jika status code bukan 200

    # Mencoba mengonversi response ke JSON, jika gagal tampilkan sebagai teks
    try:
        data = response.json()
    except ValueError:
        data = response.text

    print("Data yang diterima:")
    print(data)

except requests.exceptions.RequestException as e:
    print("Terjadi error saat mengakses API:", e)
# Out:
# Data yang diterima:
#
# <div style="border:1px solid #990000;padding-left:20px;margin:0 0 10px 0;">
#
# <h4>A PHP Error was encountered</h4>
#
# <p>Severity: Notice</p>
# <p>Message:  Undefined index: user_id_role</p>
# <p>Filename: api/Projects.php</p>
# <p>Line Number: 25</p>
#
#
# 	<p>Backtrace:</p>
#
#
#
#
#
#
# 			<p style="margin-left:10px">
# 			File: /home/nqafbps/public_html/qgate/application/controllers/api/Projects.php<br />
# 			Line: 25<br />
# 			Function: _error_handler			</p>
#
#
#
#
#
#
# 			<p style="margin-left:10px">
# 			File: /home/nqafbps/public_html/qgate/index.php<br />
# 			Line: 315<br />
# 			Function: require_once			</p>
#
#
#
#
# ...

# %%
import requests

# URL endpoint API
url = "https://webapps.bps.go.id/nqaf/qgate/api/gates/fetchAll"

# Payload dikirim sebagai data form (application/x-www-form-urlencoded)
payload = "id_project=41"

# Header yang diperlukan
headers = {
    "Content-Type": "application/x-www-form-urlencoded; charset=UTF-8",
    "X-Requested-With": "XMLHttpRequest"
}

# Cookies yang digunakan, sesuai dengan data request yang diberikan
cookies = {
    # "BIGipServeriapps_whfe01_443.app~iapps_whfe01_443_pool": "3710124042.20480.0000",
    # "ci_session": "cdb320e55f32f9043e3897aecca3ea7e4e5593f3",
    # "twk_idm_key": "ao_hIEnT1FL-QmUj1ksOA",
    # "TawkConnectionTime": "0",
    # "TS017b14ed": "0167a1c861baa5a79164c8d6b6ba8cf0ac6af0b0c05c77c5efbe86bcf48713ba10b575ee0e67280a11954e0d92d12dd24284b1b654",
    # "TS0151fc2b": "0167a1c861aa1a52e39409f77273952748b2465b12f4b47701af17e1459fa8e8b33f1bee606fbd50dffd86294a9df5e6d5810657e2",
    # "TS01038878": "0167a1c861ed411479f7a5e95d6eb582ad2615d0c13ae9f18ae4861bdacc9d15d3dad2cf5c1f429ebb5091adcbb2a2e7a7c2cac248",
    # "TS014fcb37": "0167a1c861f035acb54671fe042ba31e61133220e9a8accd2a2c445e33e56a0abd409055991473cb30a1e88e25a26ca62081593d72",
    # "TS01514aca": "0167a1c861605e1e20b4054748b8d7c30f7b8bd9414711e6984a7d5cca6046a0873b83eb198670f38803db92e022b82148d897ea59475becb8b19fea102a78be21d3dfe1f7080ea8a7cb697bbb275550665399a0d64ca9784123c0ed80e2bf57b7aaab12a119bfda2f393c76f969a5d6c3ab3bbcbd"
}

try:
    # Mengirim request POST ke endpoint dengan payload, header, dan cookies
    response = requests.post(url, data=payload, headers=headers, cookies=cookies)
    response.raise_for_status()  # Menimbulkan exception jika terjadi error (status code bukan 200)

    # Mencoba mengonversi response ke JSON, jika gagal tampilkan sebagai teks
    try:
        data = response.json()
    except ValueError:
        data = response.text

    print("Data yang diterima:")
    print(data)

except requests.exceptions.RequestException as e:
    print("Terjadi error saat mengakses API:", e)
# Out:
# Data yang diterima:
# ...

# %%
import requests

# URL endpoint API measurements
url = "https://webapps.bps.go.id/nqaf/qgate/api/measurements/fetchAll"

# Payload dikirim sebagai data form (application/x-www-form-urlencoded)
payload = "id_project=97&id_gate=255"

# Header yang diperlukan
headers = {
    "Content-Type": "application/x-www-form-urlencoded; charset=UTF-8",
    "X-Requested-With": "XMLHttpRequest"
}

# Cookies yang digunakan, sesuai dengan data request yang diberikan
cookies = {
    # "BIGipServeriapps_whfe01_443.app~iapps_whfe01_443_pool": "3710124042.20480.0000",
    # "ci_session": "ce229afd15cfb71ca5e1d9365c49dd9c5eb2bf83",
    # "twk_idm_key": "ao_hIEnT1FL-QmUj1ksOA",
    # "TawkConnectionTime": "0",
    # "TS017b14ed": "0167a1c861baa5a79164c8d6b6ba8cf0ac6af0b0c05c77c5efbe86bcf48713ba10b575ee0e67280a11954e0d92d12dd24284b1b654",
    # "TS0151fc2b": "0167a1c861aa1a52e39409f77273952748b2465b12f4b47701af17e1459fa8e8b33f1bee606fbd50dffd86294a9df5e6d5810657e2",
    # "TS01038878": "0167a1c861ed411479f7a5e95d6eb582ad2615d0c13ae9f18ae4861bdacc9d15d3dad2cf5c1f429ebb5091adcbb2a2e7a7c2cac248",
    # "TS014fcb37": "0167a1c861f035acb54671fe042ba31e61133220e9a8accd2a2c445e33e56a0abd409055991473cb30a1e88e25a26ca62081593d72",
    # "TS01514aca": "0167a1c8618751aedb0fa839d6e00046040dc1017fa29a1a4c0d1371c1ce12b8c126a492975f060f67433c3c8bade34308839bba991c83fe713ccb0ef4982d7ffa1bda5411f4a76e68b55e232ee9eb3b40c317280b314c776b71eb31bc1cb6bdc3376df851dda8ac70cfa9398d1725b71fa935255e"
}

try:
    # Mengirim request POST ke endpoint dengan payload, header, dan cookies
    response = requests.post(url, data=payload, headers=headers, cookies=cookies)
    response.raise_for_status()  # Menimbulkan exception jika status code bukan 200

    # Mencoba mengonversi response ke JSON, jika gagal tampilkan sebagai teks
    try:
        data = response.json()
    except ValueError:
        data = response.text

    print("Data yang diterima:")
    print(data)

except requests.exceptions.RequestException as e:
    print("Terjadi error saat mengakses API:", e)
# Out:
# Data yang diterima:
# ...

# %%
import requests

# URL endpoint API
url = "https://webapps.bps.go.id/nqaf/qgate/api/MProv/fetchAll/2024"

# Header yang diperlukan
headers = {
    "Accept": "*/*",
    "Accept-Encoding": "gzip, deflate, br, zstd",
    "Accept-Language": "en-US,en;q=0.9,id-ID;q=0.8,id;q=0.7",
    "X-Requested-With": "XMLHttpRequest",
    "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/133.0.0.0 Safari/537.36"
}

# Cookies sesuai dengan data request yang diberikan
cookies = {
    # "BIGipServeriapps_whfe01_443.app~iapps_whfe01_443_pool": "3710124042.20480.0000",
    # "ci_session": "13c26f853b42750d086cb5d17b82a3b78f5e7321",
    # "twk_idm_key": "ao_hIEnT1FL-QmUj1ksOA",
    # "TawkConnectionTime": "0",
    # "TS017b14ed": "0167a1c861baa5a79164c8d6b6ba8cf0ac6af0b0c05c77c5efbe86bcf48713ba10b575ee0e67280a11954e0d92d12dd24284b1b654",
    # "TS0151fc2b": "0167a1c861aa1a52e39409f77273952748b2465b12f4b47701af17e1459fa8e8b33f1bee606fbd50dffd86294a9df5e6d5810657e2",
    # "TS01038878": "0167a1c861ed411479f7a5e95d6eb582ad2615d0c13ae9f18ae4861bdacc9d15d3dad2cf5c1f429ebb5091adcbb2a2e7a7c2cac248",
    # "TS014fcb37": "0167a1c861f035acb54671fe042ba31e61133220e9a8accd2a2c445e33e56a0abd409055991473cb30a1e88e25a26ca62081593d72",
    # "TS01514aca": "0167a1c861b492fdc4857643a01015cf5cdc0f04fd47c6fe6954b72f76995dc849cbc25f4c358ab8e60de41337952ca8258cd2daa68889abce10a06d4ea146f700ce7718f8a2beecae9751e832f3715b188d048a3ed6986ac1eb02437587a1fcfb67346213cb73a5573bf4b738bfb69e7b37cbacf8"
}

try:
    # Mengirim request GET ke endpoint dengan headers dan cookies
    response = requests.get(url, headers=headers, cookies=cookies)
    response.raise_for_status()  # Menimbulkan exception jika response error (status code bukan 200)

    # Mencoba mengonversi response ke JSON; jika gagal, tampilkan sebagai teks
    try:
        data = response.json()
    except ValueError:
        data = response.text

    print("Data yang diterima:")
    print(data)

except requests.exceptions.RequestException as e:
    print("Terjadi error saat mengakses API:", e)
# Out:
# Data yang diterima:
# ...

# %%
import requests

# URL endpoint API
url = "https://webapps.bps.go.id/nqaf/qgate/api/measurements/fetchAllActions"

# Payload dikirim sebagai data form (application/x-www-form-urlencoded)
payload = "id_project=29&id_gate=101&prov=00&kab=00"

# Header yang diperlukan
headers = {
    "Content-Type": "application/x-www-form-urlencoded; charset=UTF-8",
    "X-Requested-With": "XMLHttpRequest"
}

# Cookies yang digunakan (diambil dari data request yang diberikan)
cookies = {
    # "BIGipServeriapps_whfe01_443.app~iapps_whfe01_443_pool": "3710124042.20480.0000",
    "ci_session": "13c26f853b42750d086cb5d17b82a3b78f5e7321",
    # "twk_idm_key": "ao_hIEnT1FL-QmUj1ksOA",
    # "TawkConnectionTime": "0",
    # "TS017b14ed": "0167a1c861baa5a79164c8d6b6ba8cf0ac6af0b0c05c77c5efbe86bcf48713ba10b575ee0e67280a11954e0d92d12dd24284b1b654",
    # "TS0151fc2b": "0167a1c861aa1a52e39409f77273952748b2465b12f4b47701af17e1459fa8e8b33f1bee606fbd50dffd86294a9df5e6d5810657e2",
    # "TS01038878": "0167a1c861ed411479f7a5e95d6eb582ad2615d0c13ae9f18ae4861bdacc9d15d3dad2cf5c1f429ebb5091adcbb2a2e7a7c2cac248",
    # "TS014fcb37": "0167a1c861f035acb54671fe042ba31e61133220e9a8accd2a2c445e33e56a0abd409055991473cb30a1e88e25a26ca62081593d72",
    # "TS01514aca": "0167a1c861b492fdc4857643a01015cf5cdc0f04fd47c6fe6954b72f76995dc849cbc25f4c358ab8e60de41337952ca8258cd2daa68889abce10a06d4ea146f700ce7718f8a2beecae9751e832f3715b188d048a3ed6986ac1eb02437587a1fcfb67346213cb73a5573bf4b738bfb69e7b37cbacf8"
}

try:
    # Mengirim request POST ke endpoint dengan payload, header, dan cookies
    response = requests.post(url, data=payload, headers=headers, cookies=cookies)
    response.raise_for_status()  # Memastikan response berhasil (status code 200)

    # Mencoba mengonversi response ke format JSON; jika gagal, tampilkan sebagai teks
    try:
        data = response.json()
    except ValueError:
        data = response.text

    print("Data yang diterima:")
    print(data)

except requests.exceptions.RequestException as e:
    print("Terjadi error saat mengakses API:", e)
# Out:
# Data yang diterima:
# ...

# %%
import requests

# URL endpoint API Preventives/fetchByKab
url = "https://webapps.bps.go.id/nqaf/qgate/api/Preventives/fetchByKab"

# Payload dikirim sebagai data form (application/x-www-form-urlencoded)
# Perhatikan payload ini sudah dalam bentuk URL-encoded
payload = "data%5Byear%5D=2024&data%5Bid_project%5D=29&data%5Bid_gate%5D=101&data%5Bid_measurement%5D=118&data%5Bprov%5D=00&data%5Bkab%5D=00"

# Header yang diperlukan
headers = {
    "Content-Type": "application/x-www-form-urlencoded; charset=UTF-8",
    "X-Requested-With": "XMLHttpRequest"
}

# Cookies yang digunakan, diambil dari data request yang diberikan
cookies = {
    # "BIGipServeriapps_whfe01_443.app~iapps_whfe01_443_pool": "3710124042.20480.0000",
    # "ci_session": "13c26f853b42750d086cb5d17b82a3b78f5e7321",
    "ci_session": "5503368b0cb86766c2be9ed5d9popo3c038762698865",
    # "twk_idm_key": "ao_hIEnT1FL-QmUj1ksOA",
    # "TawkConnectionTime": "0",
    # "TS017b14ed": "0167a1c861baa5a79164c8d6b6ba8cf0ac6af0b0c05c77c5efbe86bcf48713ba10b575ee0e67280a11954e0d92d12dd24284b1b654",
    # "TS0151fc2b": "0167a1c861aa1a52e39409f77273952748b2465b12f4b47701af17e1459fa8e8b33f1bee606fbd50dffd86294a9df5e6d5810657e2",
    # "TS01038878": "0167a1c861ed411479f7a5e95d6eb582ad2615d0c13ae9f18ae4861bdacc9d15d3dad2cf5c1f429ebb5091adcbb2a2e7a7c2cac248",
    # "TS014fcb37": "0167a1c861f035acb54671fe042ba31e61133220e9a8accd2a2c445e33e56a0abd409055991473cb30a1e88e25a26ca62081593d72",
    # "TS01514aca": "0167a1c861b492fdc4857643a01015cf5cdc0f04fd47c6fe6954b72f76995dc849cbc25f4c358ab8e60de41337952ca8258cd2daa68889abce10a06d4ea146f700ce7718f8a2beecae9751e832f3715b188d048a3ed6986ac1eb02437587a1fcfb67346213cb73a5573bf4b738bfb69e7b37cbacf8"
}

try:
    # Mengirim request POST dengan payload, headers, dan cookies
    response = requests.post(url, data=payload, headers=headers, cookies=cookies)
    response.raise_for_status()  # Memastikan response berhasil (status code 200)

    # Mencoba mengonversi response ke JSON, jika gagal tampilkan sebagai teks
    try:
        data = response.json()
    except ValueError:
        data = response.text

    print("Data yang diterima:")
    print(data)

except requests.exceptions.RequestException as e:
    print("Terjadi error saat mengakses API:", e)
# Out:
# Data yang diterima:
# {'status': True, 'data': [{'id': 9913, 'year': '2024', 'id_project': 29, 'id_gate': 101, 'id_measurement': 118, 'index_action': 0, 'aksi': 'Mendesain kuesioner final jauh-jauh hari (Draft)', 'pelaksana': 'TIM VHTL', 'prov': '00', 'kab': '00', 'filename': '2024-29-101-118-0-wcLhqFJAb8.pdf', 'fileurl': None, 'is_deleted': None, 'user_created': 'wahyu_sj', 'date_created': '2024-03-20 11:47:12.0000000', 'user_modified': 'wahyu_sj', 'date_modified': '2024-03-20 11:47:12.0000000', 'user_deleted': None, 'date_deleted': None}]}

# %%
import requests

# URL endpoint API Preventives/fetchByMeasurement
url = "https://webapps.bps.go.id/nqaf/qgate/api/Preventives/fetchByMeasurement"

# Payload dikirim sebagai data form (application/x-www-form-urlencoded)
payload = "year=2024&param%5Byear%5D=2024&param%5Bid_project%5D=55&param%5Bid_gate%5D=186&param%5Bid_measurement%5D=293&param%5Bprov%5D=31&param%5Bkab%5D=74"

# Header yang diperlukan
headers = {
    "Content-Type": "application/x-www-form-urlencoded; charset=UTF-8",
    "X-Requested-With": "XMLHttpRequest"
}

# Cookies yang digunakan, diambil dari data request yang diberikan
cookies = {
    # "BIGipServeriapps_whfe01_443.app~iapps_whfe01_443_pool": "3710124042.20480.0000",
    # "ci_session": "13c26f853b42750d086cb5d17b82a3b78f5e7321",
    # "twk_idm_key": "ao_hIEnT1FL-QmUj1ksOA",
    # "TawkConnectionTime": "0",
    # "TS017b14ed": "0167a1c861baa5a79164c8d6b6ba8cf0ac6af0b0c05c77c5efbe86bcf48713ba10b575ee0e67280a11954e0d92d12dd24284b1b654",
    # "TS0151fc2b": "0167a1c861aa1a52e39409f77273952748b2465b12f4b47701af17e1459fa8e8b33f1bee606fbd50dffd86294a9df5e6d5810657e2",
    # "TS01038878": "0167a1c861ed411479f7a5e95d6eb582ad2615d0c13ae9f18ae4861bdacc9d15d3dad2cf5c1f429ebb5091adcbb2a2e7a7c2cac248",
    # "TS014fcb37": "0167a1c861f035acb54671fe042ba31e61133220e9a8accd2a2c445e33e56a0abd409055991473cb30a1e88e25a26ca62081593d72",
    # "TS01514aca": "0167a1c861b492fdc4857643a01015cf5cdc0f04fd47c6fe6954b72f76995dc849cbc25f4c358ab8e60de41337952ca8258cd2daa68889abce10a06d4ea146f700ce7718f8a2beecae9751e832f3715b188d048a3ed6986ac1eb02437587a1fcfb67346213cb73a5573bf4b738bfb69e7b37cbacf8"
}

try:
    # Mengirim request POST ke endpoint dengan payload, headers, dan cookies
    response = requests.post(url, data=payload, headers=headers, cookies=cookies)
    response.raise_for_status()  # Memastikan response berhasil (status code 200)

    # Mencoba mengonversi response ke format JSON; jika gagal, tampilkan sebagai teks
    try:
        data = response.json()
    except ValueError:
        data = response.text

    print("Data yang diterima:")
    print(data)

except requests.exceptions.RequestException as e:
    print("Terjadi error saat mengakses API:", e)
# Out:
# Data yang diterima:
# ...

# %%
import requests

# URL endpoint API Projects/fetchSpesific
url = "https://webapps.bps.go.id/nqaf/qgate/api/Projects/fetchSpesific"

# Payload dikirim sebagai data form (application/x-www-form-urlencoded)
payload = "year=2025&project_id=97"

# Header yang diperlukan
headers = {
    "Content-Type": "application/x-www-form-urlencoded; charset=UTF-8",
    "X-Requested-With": "XMLHttpRequest"
}

# Cookies yang digunakan, diambil dari data request yang diberikan
cookies = {
    # "BIGipServeriapps_whfe01_443.app~iapps_whfe01_443_pool": "3710124042.20480.0000",
    "ci_session": "13c26f853b42750d086cb5d17b82a3b78f5e7321",
    # "twk_idm_key": "ao_hIEnT1FL-QmUj1ksOA",
    # "TawkConnectionTime": "0",
    # "TS017b14ed": "0167a1c861baa5a79164c8d6b6ba8cf0ac6af0b0c05c77c5efbe86bcf48713ba10b575ee0e67280a11954e0d92d12dd24284b1b654",
    # "TS0151fc2b": "0167a1c861aa1a52e39409f77273952748b2465b12f4b47701af17e1459fa8e8b33f1bee606fbd50dffd86294a9df5e6d5810657e2",
    # "TS01038878": "0167a1c861ed411479f7a5e95d6eb582ad2615d0c13ae9f18ae4861bdacc9d15d3dad2cf5c1f429ebb5091adcbb2a2e7a7c2cac248",
    # "TS014fcb37": "0167a1c861f035acb54671fe042ba31e61133220e9a8accd2a2c445e33e56a0abd409055991473cb30a1e88e25a26ca62081593d72",
    # "TS01514aca": "0167a1c861b492fdc4857643a01015cf5cdc0f04fd47c6fe6954b72f76995dc849cbc25f4c358ab8e60de41337952ca8258cd2daa68889abce10a06d4ea146f700ce7718f8a2beecae9751e832f3715b188d048a3ed6986ac1eb02437587a1fcfb67346213cb73a5573bf4b738bfb69e7b37cbacf8"
}

try:
    # Mengirim request POST ke endpoint dengan payload, headers, dan cookies
    response = requests.post(url, data=payload, headers=headers, cookies=cookies)
    response.raise_for_status()  # Memastikan response berhasil (status code 200)

    # Mencoba mengonversi response ke format JSON; jika gagal, tampilkan sebagai teks
    try:
        data = response.json()
    except ValueError:
        data = response.text

    print("Data yang diterima:")
    print(data)

except requests.exceptions.RequestException as e:
    print("Terjadi error saat mengakses API:", e)
# Out:
# Data yang diterima:
# {'year': '2025', 'project_id': '97', 'status': True, 'data': {'idp': '97', 'idr': '1', 'id': 97, 'year': '2025', 'name': 'Indikator Sustainable Development Goals (SDGs)', 'description': 'Indikator Sustainable Development Goals (SDGs)', 'id_institution': 1, 'subject_matter': '15', 'directorate': None, 'id_collection_type': '3', 'id_project_frequency': '6', 'other_project_frequency': None, 'frequency_period': None, 'id_sample_unit': '["1"]', 'other_sample_unit': None, 'is_deleted': None, 'user_created': 'ria.noviana', 'date_created': '2025-02-04 05:49:25.0000000', 'user_modified': 'ria.noviana', 'date_modified': '2025-02-04 05:49:25.0000000', 'user_deleted': None, 'date_deleted': None}}

# %%
import requests

url = "https://webapps.bps.go.id/nqaf/qgate/api/coverages/fetchAll"

# Data yang dikirim pada body request
payload = "id_project=85"

# Header yang diperlukan
headers = {
    "Content-Type": "application/x-www-form-urlencoded; charset=UTF-8",
    "Accept": "application/json, text/javascript, */*; q=0.01",
    "x-requested-with": "XMLHttpRequest",
    "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/133.0.0.0 Safari/537.36"
}

# Jika API memerlukan cookies, sertakan juga cookies berikut:
cookies = {
    
    # "ci_session": "de01cb70a5e5919ca19cad18a6e99e5c01698205",
    # "BIGipServeriapps_whfe01_443.app~iapps_whfe01_443_pool": "3710124042.20480.0000",
    # "TS014fcb37": "0167a1c86109404e660fe50b90110b393ce6e3f9ef799006bda094d2c77ce5ec7d07b30b619c511bbb2344c3799ffbb1bb507c2dc9",
    # "TS017b14ed": "0167a1c8619f979f84e38e562a4eb7700fd94be9e80e3653a689d6716b96079d4751c726b1567296b41db40a94d3d4c98654c22c90",
    # "TS01038878": "0167a1c861a1e57d369b0ccd56d3e919f6c20dbc287385c3a32ae38a8e4273ed764fdf0344e0beeee811b0940f4e2f17e180e2c16c",
    # "TS01514aca": "0167a1c861e12e0d12320c45c9cfcc49135ea0b94e014a62845ccf2f86dc8b767a6d03a3d091618d862298630fe023a384223c337d89c1ffc853611706ddb2366733d81869cbae2324bebdc615c203efeac2dec652"
}

try:
    response = requests.post(url, data=payload, headers=headers, cookies=cookies)
    response.raise_for_status()  # Akan memunculkan error jika status code bukan 200
    data = response.json()       # Mengubah respons menjadi JSON (jika formatnya JSON)
    print("Data yang diterima:")
    print(data)
except requests.exceptions.RequestException as e:
    print("Terjadi kesalahan pada request:", e)
except ValueError:
    print("Gagal mengkonversi respons ke format JSON")
# Out:
# Data yang diterima:
# ...

# %%
import requests

def fetch_by_kab():
    url = "https://webapps.bps.go.id/nqaf/qgate/api/Correctives/fetchByKab"
    payload = {
        "data[year]": "2024",
        "data[id_project]": "41",
        "data[id_gate]": "166",
        "data[id_measurement]": "260",
        "data[prov]": "00",
        "data[kab]": "00"
    }
    
    headers = {
        # "Content-Type": "application/x-www-form-urlencoded; charset=UTF-8",
        # "Accept": "*/*",
        # "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/133.0.0.0 Safari/537.36",
        # "X-Requested-With": "XMLHttpRequest"
    }
    
    response = requests.post(url, data=payload, headers=headers)
    print("Hasil dari fetchByKab API:")
    print(response.text)

if __name__ == "__main__":
    fetch_by_kab()
# Out:
# Hasil dari fetchByKab API:
# {"status":true,"data":[{"id":2696,"year":"2024","id_project":41,"id_gate":166,"id_measurement":260,"assessment":1,"index_action":0,"aksi":"Melakukan koordinasi intensif dengan SM terkait","pelaksana":"Tim IPM","prov":"00","kab":"00","filename":"2024-41-166-260-0-vnWx8qsEck.pdf","fileurl":null,"is_deleted":null,"user_created":"syukriyah.delyana","date_created":"2024-10-07 22:44:41.0000000","user_modified":"syukriyah.delyana","date_modified":"2024-10-07 22:44:41.0000000","user_deleted":null,"date_deleted":null}]}

# %%
import requests

def fetch_by_measurement():
    url = "https://webapps.bps.go.id/nqaf/qgate/api/Correctives/fetchByMeasurement"
    payload = {
        "year": "2024",
        "param[year]": "2024",
        "param[id_project]": "41",
        "param[id_gate]": "166",
        "param[id_measurement]": "260",
        "param[prov]": "00",
        "param[kab]": "00"
    }
    
    headers = {
        # "Content-Type": "application/x-www-form-urlencoded; charset=UTF-8",
        # "Accept": "*/*",
        # "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/133.0.0.0 Safari/537.36",
        # "X-Requested-With": "XMLHttpRequest"
    }
    
    response = requests.post(url, data=payload, headers=headers)
    print("Hasil dari fetchByMeasurement API:")
    print(response.text)

if __name__ == "__main__":
    fetch_by_measurement()
# Out:
# Hasil dari fetchByMeasurement API:
# {"status":true,"data":[{"id":5285,"year":"2024","id_project":41,"id_gate":166,"id_measurement":260,"assessment":1,"index_action":0,"aksi":"Melakukan koordinasi intensif dengan SM terkait","pelaksana":"Tim IPM","prov":"00","kab":"00","username":"karyono","name":"Yoyo Karyono SST","is_deleted":null,"user_created":"syukriyah.delyana","date_created":"2024-10-04 16:15:45.0000000","user_modified":"syukriyah.delyana","date_modified":"2024-10-04 16:15:45.0000000","user_deleted":null,"date_deleted":null}]}

# %%
import requests

# URL API
url = "https://webapps.bps.go.id/nqaf/qgate/api/Measurements/fetchAllAssessments"

# Payload data
payload = {
    "id_project": "29",
    "id_gate": "101",
    "prov": "11",
    "kab": "01"
}

# Header yang diperlukan
headers = {
    "Content-Type": "application/x-www-form-urlencoded; charset=UTF-8",
    "Accept": "application/json, text/javascript, */*; q=0.01",
    "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/133.0.0.0 Safari/537.36",
    "X-Requested-With": "XMLHttpRequest",
    "Origin": "https://webapps.bps.go.id",
    "Referer": "https://webapps.bps.go.id/nqaf/qgate/assessments"
}

# Cookies sesuai dengan yang diberikan
cookies = {
    # "BIGipServeriapps_whfe01_443.app~iapps_whfe01_443_pool": "3710124042.20480.0000",
    "ci_session": "d941f8508a799061fa9c1a0ba167fb16a20813fe",
    # "TS014fcb37": "0167a1c86109404e660fe50b90110b393ce6e3f9ef799006bda094d2c77ce5ec7d07b30b619c511bbb2344c3799ffbb1bb507c2dc9",
    # "TS017b14ed": "0167a1c8616f19ba03c7b572326e9bf60e46d94293d5648698ef4608ca9c517cfec9d1e67f51560a0e93f43ecdbe281eeb763f134c",
    # "TS01038878": "0167a1c861ec3f87a8ce264e3fe2029f3e5650fbf5169a1eba391b828de06a184ed123ce4b7f24e3a974a680de88bcc44786586b3e",
    # "TS0151fc2b": "0167a1c861a92544cb7f7176aaa1f675882db2fa204f045c8c5deb01dc99c1db68508eb648626a2a6f8b45aeb5e83eda3becc57dbc",
    # "dh_cookie": "ea4caa47bd811838fc72dfd2a6aabfc1",
    # "TS01514aca": "0167a1c86168c7c59d3bea9a5859050c8b4fba87c175974bceffb33eb225a594a2f30889585a7df935c02d1d158684c0afa36ee8f415f06479a93580bc8ef9f941c6f87c5c820f37ffa4b2974eabd7babb05471861161436ba68d4cfa5a02aad481dac3960c2f7f83c6af058f97a73197e4f5c1639"
}

# Mengirimkan POST request dengan cookies
response = requests.post(url, data=payload, headers=headers, cookies=cookies)

# Mengecek apakah request berhasil dan mencoba mem-parsing respons JSON
if response.ok:
    try:
        data = response.json()
        print("Data yang diterima:")
        print(data)
    except ValueError:
        print("Respons tidak dalam format JSON:")
        print(response.text)
else:
    print("Gagal mengambil data. Status code:", response.status_code)
# Out:
# Data yang diterima:
# {'status': True, 'data': [], 'dateNow': '2025-03-22'}
